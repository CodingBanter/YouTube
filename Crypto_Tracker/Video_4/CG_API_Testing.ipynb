# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

coin_list = cg.get_coins_markets(vs_currency='usd')
print(coin_list)
# Out:
# [{'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579', 'current_price': 64442, 'market_cap': 1216550907993, 'market_cap_rank': 1, 'fully_diluted_valuation': 1353568309429, 'total_volume': 31489119754, 'high_24h': 66359, 'low_24h': 63947, 'price_change_24h': 225.21, 'price_change_percentage_24h': 0.3507, 'market_cap_change_24h': 3779118975, 'market_cap_change_percentage_24h': 0.31161, 'circulating_supply': 18874237.0, 'total_supply': 21000000.0, 'max_supply': 21000000.0, 'ath': 69045, 'ath_change_percentage': -6.83118, 'ath_date': '2021-11-10T14:24:11.849Z', 'atl': 67.81, 'atl_change_percentage': 94766.75267, 'atl_date': '2013-07-06T00:00:00.000Z', 'roi': None, 'last_updated': '2021-11-15T19:55:03.324Z'}, {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum', 'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880', 'current_price': 4614.82, 'market_cap': 546415116904, 'market_cap_rank': 2, 'fully_diluted_valuation': None, 'total_volume': 17774967989, 'high_24h': 4770.73, 'low_24h': 4543.95, 'price_change_24h': 67.12, 'price_change_percentage_24h': 1.47587, 'market_cap_change_24h': 8062590516, 'market_cap_change_percentage_24h': 1.49764, 'circulating_supply': 118355318.874, 'total_supply': None, 'max_supply': None, 'ath': 4878.26, 'ath_change_percentage': -5.50586, 'ath_date': '2021-11-10T14:24:19.604Z', 'atl': 0.432979, 'atl_change_percentage': 1064540.98573, 'atl_date': '2015-10-20T00:00:00.000Z', 'roi': {'times': 94.94209742259164, 'currency': 'btc', 'percentage': 9494.209742259163}, 'last_updated': '2021-11-15T19:57:27.479Z'}, {'id': 'binancecoin', 'symbol': 'bnb', 'name': 'Binance Coin', 'image': 'https://assets.coingecko.com/coins/images/825/large/binance-coin-logo.png?1547034615', 'current_price': 640.38, 'market_cap': 107737979688, 'market_cap_rank': 3, 'fully_diluted_valuation': 107737979688, 'total_volume': 2090388259, 'high_24h': 661.26, 'low_24h': 635.37, 'price_change_24h': -7.335103879638, 'price_change_percentage_24h': -1.13246, 'market_cap_change_24h': -1209046294.8235474, 'market_cap_change_percentage_24h': -1.10976, 'circulating_supply': 168137035.9, 'total_supply': 168137035.9, 'max_supply': 168137035.9, 'ath': 686.31, 'ath_change_percentage': -6.74634, 'ath_date': '2021-05-10T07:24:17.097Z', 'atl': 0.0398177, 'atl_change_percentage': 1607240.61322, 'atl_date': '2017-10-19T00:00:00.000Z', 'roi': None, 'last_updated': '2021-11-15T19:56:15.440Z'}, {'id': 'tether', 'symbol': 'usdt', 'name': 'Tether', 'image': 'https://assets.coingecko.com/coins/images/325/large/Tether-logo.png?1598003707', 'current_price': 1.01, 'market_cap': 75168076616, 'market_cap_rank': 4, 'fully_diluted_valuation': None, 'total_volume': 58196904405, 'high_24h': 1.01, 'low_24h': 0.998746, 'price_change_24h': 0.00321693, 'price_change_percentage_24h': 0.32104, 'market_cap_change_24h': 207527699, 'market_cap_change_percentage_24h': 0.27685, 'circulating_supply': 74756886939.0859, 'total_supply': 74756886939.0859, 'max_supply': None, 'ath': 1.32, 'ath_change_percentage': -24.00056, 'ath_date': '2018-07-24T00:00:00.000Z', 'atl': 0.572521, 'atl_change_percentage': 75.63462, 'atl_date': '2015-03-02T00:00:00.000Z', 'roi': None, 'last_updated': '2021-11-15T19:52:21.221Z'}, {'id': 'solana', 'symbol': 'sol', 'name': 'Solana', 'image': 'https://assets.coingecko.com/coins/images/4128/large/Solana.jpg?1635329178', 'current_price': 240.2, 'market_cap': 72885180394, 'market_cap_rank': 5, 'fully_diluted_valuation': None, 'total_volume': 2348537122, 'high_24h': 246.09, 'low_24h': 234.83, 'price_change_24h': 5.37, 'price_change_percentage_24h': 2.28838, 'market_cap_change_24h': 1946897720, 'market_cap_change_percentage_24h': 2.7445, 'circulating_supply': 303211906.6333, 'total_supply': 508180963.57, 'max_supply': None, 'ath': 259.96, 'ath_change_percentage': -7.62911, 'ath_date': '2021-11-06T21:54:35.825Z', 'atl': 0.500801, 'atl_change_percentag ...

# %%
for coin in coin_list:
    print(coin['name'])
    print(coin['current_price'])
# Out:
# Bitcoin
# 64442
# Ethereum
# 4614.82
# Binance Coin
# 640.38
# Tether
# 1.01
# Solana
# 240.2
# Cardano
# 2.04
# XRP
# 1.19
# Polkadot
# 45.86
# USD Coin
# 1.0
# Dogecoin
# 0.259944
# Shiba Inu
# 5.492e-05
# Terra
# 49.35
# Avalanche
# 96.09
# Litecoin
# 265.44
# Wrapped Bitcoin
# 64336
# Chainlink
# 32.94
# Binance USD
# 1.0
# Bitcoin Cash
# 673.37
# Algorand
# 1.93
# Polygon
# 1.72
# Crypto.com Coin
# 0.462472
# VeChain
# 0.168504
# Uniswap
# 24.32
# Stellar
# 0.386792
# Axie Infinity
# 142.93
# Cosmos
# 32.22
# TRON
# 0.126342
# Internet Computer
# 47.56
# Dai
# 1.0
# FTX Token
# 55.94
# Filecoin
# 61.76
# cETH
# 92.4
# Ethereum Classic
# 55.37
# OKB
# 27.02
# Theta Network
# 6.99
# Lido Staked Ether
# 4570.2
# Hedera
# 0.43062
# Fantom
# 2.53
# Elrond
# 316.07
# Near
# 11.38
# TerraUSD
# 1.01
# The Graph
# 1.06
# Tezos
# 5.8
# Monero
# 273.63
# Helium
# 47.87
# EOS
# 4.91
# PancakeSwap
# 18.61
# cDAI
# 0.02174015
# Decentraland
# 3.25
# Flow
# 13.54
# Aave
# 305.93
# Klaytn
# 1.54
# eCash
# 0.00020199
# Olympus
# 874.31
# Kusama
# 420.01
# Quant
# 275.34
# THORChain
# 12.39
# IOTA
# 1.31
# Loopring
# 2.92
# cUSDC
# 0.02238404
# NEO
# 48.09
# Arweave
# 67.27
# Bitcoin SV
# 176.81
# Kadena
# 20.4
# Harmony
# 0.295194
# Bitcoin Cash ABC
# 160.26
# Chiliz
# 0.546552
# Enjin Coin
# 3.08
# Magic Internet Money
# 1.01
# LEO Token
# 2.98
# Amp
# 0.057098
# Maker
# 3037.07
# Huobi BTC
# 64376
# Stacks
# 2.43
# BitTorrent
# 0.0038577
# The Sandbox
# 2.81
# Holo
# 0.01385124
# Dash
# 230.61
# Waves
# 23.58
# Zcash
# 196.46
# Compound
# 341.22
# Sushi
# 10.72
# SafeMoon
# 3.61e-06
# KuCoin Token
# 26.55
# IoTeX
# 0.209326
# NEXO
# 3.54
# Celo
# 5.69
# Celsius Network
# 4.65
# Theta Fuel
# 0.340336
# Synthetix Network Token
# 9.8
# NEM
# 0.196049
# Qtum
# 17.01
# Basic Attention Token
# 1.17
# Livepeer
# 71.36
# Spell Token
# 0.02328811
# ICON
# 2.54
# Huobi Token
# 10.77
# Wonderland
# 8267.39
# ECOMI
# 0.00682169
# OMG Network
# 11.42
